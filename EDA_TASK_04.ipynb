# %% [markdown]
# AICP INTERNSHIP WEEK-04

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Reading the CSV file
menu_data = pd.read_csv('menu.csv')

# %%
# Statistical summary for all columns
stats_summary = menu_data.describe()
print("Statistical Summary for all columns:")
print(stats_summary)

# Maximum values for specified attributes
max_values = menu_data[['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars',
                        'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
                        'Calcium (% Daily Value)', 'Iron (% Daily Value)']].max()
print("\nMaximum values for specified attributes:")
print(max_values)
# Out:
# Statistical Summary for all columns:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
# Selecting only numeric columns for correlation computation
numeric_columns = menu_data.select_dtypes(include=np.number)

# Compute correlation matrix
correlation_matrix = numeric_columns.corr()

# Plotting correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Setting the style of seaborn
sns.set_style("whitegrid")

# Plotting boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Calories', data=menu_data)
plt.title('Calories vs Category')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Find the item with the highest quantity for each attribute
max_calories_item = menu_data.loc[menu_data['Calories'].idxmax()]['Item']
max_total_fat_item = menu_data.loc[menu_data['Total Fat'].idxmax()]['Item']
max_carbohydrates_item = menu_data.loc[menu_data['Carbohydrates'].idxmax()]['Item']
max_dietary_fiber_item = menu_data.loc[menu_data['Dietary Fiber'].idxmax()]['Item']
max_sugars_item = menu_data.loc[menu_data['Sugars'].idxmax()]['Item']
max_protein_item = menu_data.loc[menu_data['Protein'].idxmax()]['Item']
max_vitamin_a_item = menu_data.loc[menu_data['Vitamin A (% Daily Value)'].idxmax()]['Item']
max_vitamin_c_item = menu_data.loc[menu_data['Vitamin C (% Daily Value)'].idxmax()]['Item']
max_calcium_item = menu_data.loc[menu_data['Calcium (% Daily Value)'].idxmax()]['Item']
max_iron_item = menu_data.loc[menu_data['Iron (% Daily Value)'].idxmax()]['Item']

# Find the maximum value for each attribute
max_calories = menu_data['Calories'].max()
max_total_fat = menu_data['Total Fat'].max()
max_carbohydrates = menu_data['Carbohydrates'].max()
max_dietary_fiber = menu_data['Dietary Fiber'].max()
max_sugars = menu_data['Sugars'].max()
max_protein = menu_data['Protein'].max()
max_vitamin_a = menu_data['Vitamin A (% Daily Value)'].max()
max_vitamin_c = menu_data['Vitamin C (% Daily Value)'].max()
max_calcium = menu_data['Calcium (% Daily Value)'].max()
max_iron = menu_data['Iron (% Daily Value)'].max()

# Displaying summary
summary = f"""
Item with the highest quantity for each attribute:
- Calories: {max_calories_item}
- Total Fat: {max_total_fat_item}
- Carbohydrates: {max_carbohydrates_item}
- Dietary Fiber: {max_dietary_fiber_item}
- Sugars: {max_sugars_item}
- Protein: {max_protein_item}
- Vitamin A (% Daily Value): {max_vitamin_a_item}
- Vitamin C (% Daily Value): {max_vitamin_c_item}
- Calcium (% Daily Value): {max_calcium_item}
- Iron (% Daily Value): {max_iron_item}

Maximum value for each attribute:
- Calories: {max_calories}
- Total Fat: {max_total_fat}
- Carbohydrates: {max_carbohydrates}
- Dietary Fiber: {max_dietary_fiber}
- Sugars: {max_sugars}
- Protein: {max_protein}
- Vitamin A (% Daily Value): {max_vitamin_a}
- Vitamin C (% Daily Value): {max_vitamin_c}
- Calcium (% Daily Value): {max_calcium}
- Iron (% Daily Value): {max_iron}
"""
print(summary)
# Out:
# Item with the highest quantity for each attribute:
# - Calories: Chicken McNuggets (40 piece)
# - Total Fat: Chicken McNuggets (40 piece)
# - Carbohydrates: Chocolate Shake (Large)
# - Dietary Fiber: Big Breakfast with Hotcakes (Large Biscuit)
# - Sugars: McFlurry with M&M’s Candies (Medium)
# - Protein: Chicken McNuggets (40 piece)
# - Vitamin A (% Daily Value): Premium Bacon Ranch Salad (without Chicken)
# - Vitamin C (% Daily Value): Minute Maid Orange Juice (Large)
# - Calcium (% Daily Value): Strawberry Shake (Large)
# - Iron (% Daily Value): Big Breakfast with Hotcakes (Regular Biscuit)
#
# Maximum value for each attribute:
# - Calories: 1880
# - Total Fat: 118.0
# - Carbohydrates: 141
# - Dietary Fiber: 7
# - Sugars: 128
# - Protein: 87
# - Vitamin A (% Daily Value): 170
# - Vitamin C (% Daily Value): 240
# - Calcium (% Daily Value): 70
# - Iron (% Daily Value): 40

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Calories
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Calories', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Calories vs Category')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-25-5d9f21d7b0ae>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Calories', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Total Fat
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Total Fat', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Total Fat vs Category')
plt.xlabel('Category')
plt.ylabel('Total Fat')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-26-378dfb185bb7>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Total Fat', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Carbohydrates
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Carbohydrates', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Carbohydrates vs Category')
plt.xlabel('Category')
plt.ylabel('Carbohydrates')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-27-9e84ccc61851>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Carbohydrates', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Dietary Fiber
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Dietary Fiber', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Dietary Fiber vs Category')
plt.xlabel('Category')
plt.ylabel('Dietary Fiber')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-28-c0faaac5b08b>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Dietary Fiber', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Sugars
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Sugars', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Sugars vs Category')
plt.xlabel('Category')
plt.ylabel('Sugars')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-29-5c1da9ee3806>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Sugars', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Protein
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Protein', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Protein vs Category')
plt.xlabel('Category')
plt.ylabel('Protein')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-30-cc72641e6ae3>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Protein', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Vitamin A (% Daily Value)
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Vitamin A (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Vitamin A (% Daily Value) vs Category')
plt.xlabel('Category')
plt.ylabel('Vitamin A (% Daily Value)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-31-c9b5827cd697>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Vitamin A (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Vitamin C (% Daily Value)
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Vitamin A (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Vitamin C (% Daily Value) vs Category')
plt.xlabel('Category')
plt.ylabel('Vitamin C (% Daily Value)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-32-d90763552e14>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Vitamin A (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Calcium (% Daily Value)
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Vitamin A (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Calcium (% Daily Value) vs Category')
plt.xlabel('Category')
plt.ylabel('Calcium (% Daily Value)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-33-cfff26da3a4a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Vitamin A (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Define the order of categories
category_order = ['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads', 'Snacks & Sides',
                  'Desserts', 'Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

# Plotting stripplot for each category against Iron (% Daily Value)
plt.figure(figsize=(12, 8))
sns.stripplot(x='Category', y='Iron (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')
plt.title('Iron (% Daily Value) vs Category')
plt.xlabel('Category')
plt.ylabel('Iron (% Daily Value)')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-34-fcd8d284e944>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='Category', y='Iron (% Daily Value)', data=menu_data, order=category_order, jitter=True, palette='bright')

# %%
# Plotting horizontal bar graph for items in each category against Calories
plt.figure(figsize=(12, 8))
sns.barplot(x='Calories', y='Item', data=menu_data[menu_data['Category'] == 'Beef & Pork'], color='skyblue')
plt.title('Calories of Items in Beef & Pork Category')
plt.xlabel('Calories')
plt.ylabel('Item')
plt.show()
